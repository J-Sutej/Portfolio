# %% [markdown]
# # Machine Learning Model
# This project is a reproducible project from data professor from YouTube, using machine learning to predict logS valuable.

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/refs/heads/master/delaney_solubility_with_descriptors.csv')
df.head()
# Out:
#    MolLogP    MolWt  NumRotatableBonds  AromaticProportion  logS
# 0   2.5954  167.850                0.0                 0.0 -2.18
# 1   2.3765  133.405                0.0                 0.0 -2.00
# 2   2.5938  167.850                1.0                 0.0 -1.74
# 3   2.0289  133.405                1.0                 0.0 -1.48
# 4   2.9189  187.375                1.0                 0.0 -3.04

# %% [markdown]
# ### Data Preparation
# #### Data separation as X and Y

# %%
y = df['logS']
y
# Out:
# 0      -2.180
# 1      -2.000
# 2      -1.740
# 3      -1.480
# 4      -3.040
#         ...
# 1139    1.144
# 1140   -4.925
# 1141   -3.893
# 1142   -3.790
# 1143   -2.581
# Name: logS, Length: 1144, dtype: float64

# %%
# drop logS column to consider only x value for prediction
x = df.drop('logS', axis = 1)
x
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1139  1.98820  287.343                8.0            0.000000
# 1140  3.42130  286.114                2.0            0.333333
# 1141  3.60960  308.333                4.0            0.695652
# 1142  2.56214  354.815                3.0            0.521739
# 1143  2.02164  179.219                1.0            0.461538
#
# [1144 rows x 4 columns]

# %% [markdown]
# ### Data Splitting
# Due to seperated training data and test data, ML requires some test data that is not similar to training data to prevent the predictable pattern and unpredictable result that they have not alreaddy known the result.

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state= 100)

# %%
print(len(x_train)) # This dataset is collected in tuple by 80% of data.
print(len(x_test))
# Out:
# 915
# 229

# %%
x_train
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 961   1.35060  151.165                1.0            0.545455
# 666   2.97670  112.216                1.0            0.000000
# 1097  1.34990  242.344                4.0            0.000000
# 449   1.01110   94.939                0.0            0.000000
# 737   2.08340  365.842                3.0            0.500000
# ...       ...      ...                ...                 ...
# 570   3.15380  284.746                1.0            0.600000
# 452   2.78888  276.915                0.0            0.545455
# 679   3.26040  253.367                6.0            0.352941
# 671   6.37200  376.496                9.0            0.642857
# 669   1.56890  166.176                2.0            0.500000
#
# [915 rows x 4 columns]

# %% [markdown]
# ## Model Building
# Using linear regression

# %% [markdown]
# #### Training the model

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train) # build the model by using train data
# Out:
# LinearRegression()

# %% [markdown]
# #### Applying the model to make a prediction

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %%
y_lr_test_pred,
# Out:
# (array([-1.86302593, -2.39899695, -2.72669859, -1.49921521, -7.16364086,
#         -2.92499018, -2.13983454, -2.05533056, -9.2606527 , -4.98398076,
#         -2.40221535, -2.84360634, -0.81638576, -2.73436627, -5.30940429,
#         -0.579822  , -2.32467014, -3.54988545,  0.38519483, -4.570615  ,
#         -2.41603079, -5.95470291, -3.7590004 , -1.864942  , -7.1598029 ,
#         -4.21320911, -5.61003084, -2.04738558, -3.68409767, -6.61666454,
#         -1.86355809, -1.95138777, -2.89217747, -4.90486194, -4.3572018 ,
#         -2.81864119, -0.74201357, -2.32467014, -3.71023406, -3.74361266,
#         -1.83389538, -7.25828399, -6.78854991, -3.7252214 , -2.96974663,
#         -8.55873215, -1.95272163, -3.5904812 , -4.3548347 , -4.39042031,
#         -4.62965483, -3.01655938, -2.91205537,  2.17629842, -3.65135367,
#         -2.98446064, -3.39323137, -4.52999392, -5.86294044, -0.65239625,
#         -4.99326097,  2.01321917, -3.86879934, -6.45309157, -2.80532066,
# ...

# %%
y_lr_test_pred
# Out:
# array([-1.86302593, -2.39899695, -2.72669859, -1.49921521, -7.16364086,
#        -2.92499018, -2.13983454, -2.05533056, -9.2606527 , -4.98398076,
#        -2.40221535, -2.84360634, -0.81638576, -2.73436627, -5.30940429,
#        -0.579822  , -2.32467014, -3.54988545,  0.38519483, -4.570615  ,
#        -2.41603079, -5.95470291, -3.7590004 , -1.864942  , -7.1598029 ,
#        -4.21320911, -5.61003084, -2.04738558, -3.68409767, -6.61666454,
#        -1.86355809, -1.95138777, -2.89217747, -4.90486194, -4.3572018 ,
#        -2.81864119, -0.74201357, -2.32467014, -3.71023406, -3.74361266,
#        -1.83389538, -7.25828399, -6.78854991, -3.7252214 , -2.96974663,
#        -8.55873215, -1.95272163, -3.5904812 , -4.3548347 , -4.39042031,
#        -4.62965483, -3.01655938, -2.91205537,  2.17629842, -3.65135367,
#        -2.98446064, -3.39323137, -4.52999392, -5.86294044, -0.65239625,
#        -4.99326097,  2.01321917, -3.86879934, -6.45309157, -2.80532066,
# ...

# %% [markdown]
# ### Evaluate model performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse =mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test,y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
lr_results = pd.DataFrame(['Linear Regression', lr_train_mse,lr_train_r2,lr_test_mse,lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
lr_results
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear Regression     1.001621    0.769125  1.046188  0.771437

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Training Model

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth= 2 , random_state= 100)
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# ### Applying the model to make a prediction

# %%
y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred = rf.predict(x_test)

# %% [markdown]
# ### Evaluate model performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

rf_train_mse =mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test,y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random Forest', rf_train_mse,rf_train_r2,rf_test_mse,rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method Training MSE Training R2  Test MSE   Test R2
# 0  Random Forest     1.005422    0.768249  1.262438  0.724193

# %% [markdown]
# ### Model Comparison

# %%
df_models = pd.concat([lr_results,rf_results], axis =0)
df_models
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear Regression     1.001621    0.769125  1.046188  0.771437
# 0      Random Forest     1.005422    0.768249  1.262438  0.724193

# %%
df_models.reset_index(drop= True)
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear Regression     1.001621    0.769125  1.046188  0.771437
# 1      Random Forest     1.005422    0.768249  1.262438  0.724193

# %% [markdown]
# ## Data Visualization of prediction results

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize= (5,5))
plt.scatter(x= y_train, y= y_lr_train_pred, alpha= 0.3) # alpha make dots lighter

z = np.polyfit(y_train,y_lr_train_pred, 1) # create trend line
p = np.poly1d(z)

plt.plot(y_train, p(y_train), 'Red')
plt.ylabel('Predict LogS')
plt.xlabel('Experimental LogS')
plt.plot()
# Out:
# []
